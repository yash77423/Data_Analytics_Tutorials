# %%
from pylab import *
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([0,2,3,4],[1,4,9,16], 'ro')
plt.show()

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
import math
import numpy as np
t = np.arange(0,2.5,0.1)
y1 = np.sin(np.pi*t)
y2 = np.sin(np.pi*t+np.pi/2)
y3 = np.sin(np.pi*t-np.pi/2)
plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')

# %%
plt.plot([1,2,4,2,1,0,1,2,1,4],linewidth=2.0)

# %%
t = np.arange(0,5,0.1)
y1 = np.sin(2*np.pi*t)
y2 = np.sin(2*np.pi*t)

# %%
plt.subplot(211)
plt.plot(t,y1,'b-.')
plt.subplot(212)
plt.plot(t,y2,'r--')

# %%
plt.subplot(121)
plt.plot(t,y1,'b-.')
plt.subplot(122)
plt.plot(t,y2,'r--')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.xlabel('Counting')
plt.ylabel('Square values')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1.1,12,r'$y = x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.4})
#plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1.1,12,r'$y = x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.4})
#plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.legend(['First series'])

# %%
import matplotlib.pyplot as plt
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1.1,12,'$y = x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.4})
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['First series','Second series','Third series'],loc=3)

# %%
# %save my_first_chart4 14
# Out:
# The following commands were written to file `my_first_chart4.py`:
# import matplotlib.pyplot as plt
# plt.axis([0,5,0,20])
# plt.title('My first plot',fontsize=20,fontname='Times New Roman')
# plt.xlabel('Counting',color='gray')
# plt.ylabel('Square values',color='gray')
# plt.text(1,1.5,'First')
# plt.text(2,4.5,'Second')
# plt.text(3,9.5,'Third')
# plt.text(4,16.5,'Fourth')
# plt.text(1.1,12,'$y = x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.4})
# plt.grid(True)
# plt.plot([1,2,3,4],[1,4,9,16],'ro')
# plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
# plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
# plt.legend(['First series','Second series','Third series'],loc=3)

# %%
# %load my_first_chart2.py
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1.1,12,r'$y = x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.4})
#plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.legend(['First series'])

# %%
# %run my_first_chart4.py

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1.1,12,'$y = x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.4})
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['First series','Second series','Third series'],loc=4)
plt.savefig('my_chart.png')

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
events = [datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.
date(2015,2,3),datetime.date(2015,2,21),datetime.date(2015,3,15),datetime.
date(2015,3,24),datetime.date(2015,4,8),datetime.date(2015,4,24)]
readings = [12,22,25,20,18,15,17,14]
plt.plot(events,readings)

# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%Y-%m')
events = [datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.
date(2015,2,3),datetime.date(2015,2,21),datetime.date(2015,3,15),datetime.
date(2015,3,24),datetime.date(2015,4,8),datetime.date(2015,4,24)]
readings = [12,22,25,20,18,15,17,14]
fig, ax = plt.subplots()
plt.plot(events,readings)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)

# %%
dir(matplotlib)
# Out:
# ['ExecutableNotFoundError',
#  'MatplotlibDeprecationWarning',
#  'MutableMapping',
#  'Parameter',
#  'Path',
#  'RcParams',
#  '_ExecInfo',
#  '_VersionInfo',
#  '__bibtex__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_add_data_doc',
#  '_afm',
#  '_api',
#  '_blocking_input',
#  '_c_internal_utils',
#  '_check_versions',
#  '_cm',
#  '_cm_listed',
#  '_color_data',
#  '_constrained_layout',
#  '_deprecated_ignore_map',
#  '_deprecated_map',
#  '_deprecated_remain_as_none',
#  '_docstring',
#  '_ensure_handler',
#  '_enums',
#  '_fontconfig_pattern',
#  '_get_config_or_cache_dir',
#  '_get_executable_info',
#  '_get_ssl_context',
#  '_get_version',
#  '_get_xdg_cache_dir',
#  '_get_xdg_config_dir',
#  '_image',
#  '_init_tests',
#  '_label_from_arg',
#  '_layoutgrid',
#  '_log',
#  '_logged_cached',
#  '_mathtext',
#  '_mathtext_data',
# ...

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  'UTC',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
help(matplotlib)
# Out:
# Help on package matplotlib:
#
# NAME
#     matplotlib - An object-oriented plotting library.
#
# DESCRIPTION
#     A procedural interface is provided by the companion pyplot module,
#     which may be imported directly, e.g.::
#
#         import matplotlib.pyplot as plt
#
#     or using ipython::
#
#         ipython
#
#     at your terminal, followed by::
#
#         In [1]: %matplotlib
#         In [2]: import matplotlib.pyplot as plt
#
#     at the ipython shell prompt.
#
#     For the most part, direct use of the explicit object-oriented library is
#     encouraged when programming; the implicit pyplot interface is primarily for
#     working interactively. The exceptions to this suggestion are the pyplot
#     functions `.pyplot.figure`, `.pyplot.subplot`, `.pyplot.subplots`, and
#     `.pyplot.savefig`, which can greatly simplify scripting.  See
#     :ref:`api_interfaces` for an explanation of the tradeoffs between the implicit
#     and explicit interfaces.
#
# ...

# %% [markdown]
# Types of Charts:
#     Line chart -- a sequence of data points connected by a line.
#      display a family of functions such as y = sin (n * x) / x

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
...: y = np.sin(3*x)/x
...: plt.plot(x,y)

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)
...: y = np.sin(1*x)/x
...: y2 = np.sin(2*x)/x
...: y3 = np.sin(3*x)/x
...: plt.plot(x,y)
...: plt.plot(x,y2)
...: plt.plot(x,y3)

# %%
plt.plot(x,y,'k--',linewidth=3)
...: plt.plot(x,y2,'m-.')
...: plt.plot(x,y3,color='g',linestyle='--')

# %%
plt.plot(x,y,color='b')
...: plt.plot(x,y2,color='r')
...: plt.plot(x,y3,color='g')
...: plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi], #ticks
[r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])  # labels
...: plt.yticks([-1,0,+1,+2,+3],
[r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])
# Out:
# ([<matplotlib.axis.YTick at 0x1d409f95110>,
# ...
#  [Text(0, -1, '$-1$'),
#   Text(0, 0, '$0$'),
#   Text(0, 1, '$+1$'),
#   Text(0, 2, '$+2$'),
#   Text(0, 3, '$+3$')])

# %% [markdown]
# Line Charts with pandas

# %%
data = {'series1':[1,3,4,3,5],'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
data
# Out:
# {'series1': [1, 3, 4, 3, 5],
#  'series2': [2, 4, 5, 2, 4],
#  'series3': [3, 2, 3, 1, 3]}

# %%
plt.plot(np.arange(5),data["series1"])
plt.plot(np.arange(5),data["series2"])
plt.plot(np.arange(5),data["series3"])
plt.legend(data, loc='upper left')

# %%
import matplotlib.pyplot as plt
...: import numpy as np
...: import pandas as pd
...: data = {'series1':[1,3,4,3,5], 'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
...: df = pd.DataFrame(data)
...: x = np.arange(5)
...: plt.axis([0,5,0,7])
plt.plot(x,df)
plt.legend(data, loc=2)

# %% [markdown]
# Histogram: A histogram consists of adjacent rectangles erected on the x axis, split into discrete intervals called bins, and with an area proportional to the frequency of the occurrences for that bin. This kind of visualization is commonly used in statistical studies about distribution of sample.
# n,bins,patches = plt.hist(pop,bins=20)

# %%
pop = np.random.randint(0,10,10)   #low, high, size
pop
# Out:
# array([7, 6, 7, 3, 5, 5, 6, 8, 8, 8])

# %%
plt.hist(pop)
# Out:
# (array([1., 0., 0., 0., 2., 0., 2., 0., 2., 3.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Bar Chart It is very similar to a histogram but in this case the x axis is not used to reference numerical values but categories

# %%
index = [0,1,2,3,4]
...: values = [5,7,3,4,6]
...: plt.bar(index,values)
# Out:
# <BarContainer object of 5 artists>

# %%
index = np.arange(5)
...: values1 = [5,7,3,4,6]
...: plt.bar(index,values1)
...: plt.xticks(index+0.4,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x2157c1e3110>,
# ...
#  [Text(0.4, 0, 'A'),
#   Text(1.4, 0, 'B'),
#   Text(2.4, 0, 'C'),
#   Text(3.4, 0, 'D'),
#   Text(4.4, 0, 'E')])

# %%
index = np.arange(5)
...: values1 = [5,7,3,4,6]
...: plt.title('A Horizontal Bar Chart')
...: plt.barh(index,values1)
...: plt.yticks(index+0.4,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.YTick at 0x2157c436290>,
# ...
#  [Text(0, 0.4, 'A'),
#   Text(0, 1.4, 'B'),
#   Text(0, 2.4, 'C'),
#   Text(0, 3.4, 'D'),
#   Text(0, 4.4, 'E')])

# %%
index = np.arange(5)
...: values1 = [5,7,3,4,6]
...: values2 = [6,6,4,5,7]
...: values3 = [5,6,5,4,6]
...: bw = 0.3
...: plt.axis([0,5,0,8])
...: plt.title('A Multiseries Bar Chart',fontsize=20)
...: plt.bar(index,values1,bw,color='b')
...: plt.bar(index+bw,values2,bw,color='g')
...: plt.bar(index+2*bw,values3,bw,color='r')
...: plt.xticks(index+1.5*.3,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x1d40b1d7990>,
# ...
#  [Text(0.44999999999999996, 0, 'A'),
#   Text(1.45, 0, 'B'),
#   Text(2.45, 0, 'C'),
#   Text(3.45, 0, 'D'),
#   Text(4.45, 0, 'E')])

# %%
index = np.arange(5)
...: values1 = [5,7,3,4,6]
...: values2 = [6,6,4,5,7]
...: values3 = [5,6,5,4,6]
...: bw = 0.3
...: plt.axis([0,8,0,5])
...: plt.title('A Multiseries Horizontal Bar Chart',fontsize=20)
...: plt.barh(index,values1,bw,color='b')
...: plt.barh(index+bw,values2,bw,color='g')
...: plt.barh(index+2*bw,values3,bw,color='r')
...: plt.yticks(index+0.4,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.YTick at 0x1d40c290c90>,
# ...
#  [Text(0, 0.4, 'A'),
#   Text(0, 1.4, 'B'),
#   Text(0, 2.4, 'C'),
#   Text(0, 3.4, 'D'),
#   Text(0, 4.4, 'E')])

# %%
series1 = np.array([3,4,5,3])
...: series2 = np.array([1,2,2,5])
...: series3 = np.array([2,3,3,4])
...: index = np.arange(4)
...: plt.axis([0,4,0,15])
...: plt.bar(index,series1,color='r')
...: plt.bar(index,series2,color='b',bottom=series1)
...: plt.bar(index,series3,color='g',bottom=(series2+series1))
...: plt.xticks(index+0.4,['Jan15','Feb15','Mar15','Apr15'])
# Out:
# ([<matplotlib.axis.XTick at 0x1d40c330710>,
# ...
#  [Text(0.4, 0, 'Jan15'),
#   Text(1.4, 0, 'Feb15'),
#   Text(2.4, 0, 'Mar15'),
#   Text(3.4, 0, 'Apr15')])

# %%
series1 = np.array([3,4,5,3])
...: series2 = np.array([1,2,2,5])
...: series3 = np.array([2,3,3,4])
...: index = np.arange(4)
...: plt.axis([0,15,0,4])
...: plt.barh(index,series1,color='r')
...: plt.barh(index,series2,color='b',left=series1)
...: plt.barh(index,series3,color='g',left=(series2+series1))
...: plt.yticks(index+0.4,['Jan15','Feb15','Mar15','Apr15'])
# Out:
# ([<matplotlib.axis.YTick at 0x1d40c2f4850>,
# ...
#  [Text(0, 0.4, 'Jan15'),
#   Text(0, 1.4, 'Feb15'),
#   Text(0, 2.4, 'Mar15'),
#   Text(0, 3.4, 'Apr15')])

# %% [markdown]
# Pie Charts An alternative way to display data to the bar charts is the pie chart

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
...: values = [10,30,45,15]
...: colors = ['yellow','green','red','blue']
...: plt.pie(values,labels=labels,colors=colors)
...: plt.axis('equal')
# Out:
# (-1.0999990177876953,
#  1.0999999532279854,
#  -1.0999990177907812,
#  1.0999999532281324)

# %%
labels = ['Nokia','Samsung','Apple','Lumia']
...: values = [10,30,45,15]
...: colors = ['yellow','green','red','blue']
...: explode = [0.3,0,0,0]
...: plt.title('A Pie Chart')
...: plt.pie(values,labels=labels,colors=colors,explode=explode,startangle=180)
...: plt.axis('equal')
# Out:
# (-1.3995827554052758,
#  1.1142648655104235,
#  -1.0999999532281324,
#  1.0999990177907812)

# %%
gs = plt.GridSpec(3,3)
...: fig = plt.figure(figsize=(6,6))
...: fig.add_subplot(gs[1,:2])
...: fig.add_subplot(gs[0,:2])
...: fig.add_subplot(gs[2,0])
...: fig.add_subplot(gs[:2,2])
...: fig.add_subplot(gs[2,1:])
# Out:
# <Axes: >

# %%
gs = plt.GridSpec(3,3)
...: fig = plt.figure(figsize=(6,6))
...: x = [0,1,2,3,4]
...: y = [5,7,3,4,6]
...: x1 = np.array([1,3,2,5])
...: y1 = np.array([4,3,7,2])
...: x2 = np.arange(5)
...: y2 = np.array([3,2,4,6,4])
...: s1 = fig.add_subplot(gs[1,:2])
...: s1.plot(x,y,'r')
...: s2 = fig.add_subplot(gs[0,:2])
...: s2.bar(x2,y2)
...: s3 = fig.add_subplot(gs[2,0])
...: s3.barh(x2,y2,color='g')
...: s4 = fig.add_subplot(gs[:2,2])
...: s4.plot(x2,y2,'k')
...: s5 = fig.add_subplot(gs[2,1:])
...: s5.plot(x1,y1,'b^',x2,y2,'yo')

# %% [markdown]
# Box Plot
# A box plot gives a five-number summary of a set of data which is-
#
# Minimum – It is the minimum value in the dataset excluding the outliers
# First Quartile (Q1) – 25% of the data lies below the First (lower) Quartile.
# Median (Q2) – It is the mid-point of the dataset. Half of the values lie below it and half above.
# Third Quartile (Q3) – 75% of the data lies below the Third (Upper) Quartile.
# Maximum – It is the maximum value in the dataset excluding the outliers.

# %%
np.random.seed(10)
data = np.random.normal(100, 20, 200)
#data =[100, 70, 91, 58, 92, 35, 45, 77, 10, 200]
fig = plt.figure(figsize =(10, 7))
# Creating plot
plt.boxplot(data) 
# show plot
plt.show()

# %%
np.random.seed(10)
 
data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

bp = plt.boxplot(data)
